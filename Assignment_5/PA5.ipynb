# %% [markdown]
# # Programming Assignment 5 - Build your own Conventional Neural Network
#
# After completing this project, you will be able to do the following:
#
# - Build neural network conveniently.
# - Configure with different regularization methods: Dropout, l1 or l2 regulation.
#
# - **574 Only**: Fine tune pre-trained model to build your own projects.
#
# # Dataset
#
# This dataset is provided by our current research project, which utilize 20 kHz acoustic sensing to sense ASL gestures. All the 10 ASL words perform by 5 subjects. All images are generated by using the short-time Fourier transform (STFT) to calculate a spectrogram as the feature representation of the reflected near-ultrasound waves. Based on the Doppler effect, sign language gestures, including both hands and arms, will cause phase and frequency changes of the reflected sonic wave. The spectrogram contains information in both frequency and time domains. The spectrogram is also defined as the Power Spectral Density of the function:
# \begin{equation}
#     \textrm{spectrogram}\{x(t)\}(\tau,\omega)\equiv |X(\tau,\omega)|^{2}= \left| \sum^{\infty}_{n=-\infty}x[n]\omega[n-m]e^{-j\omega n}\right|^{2}
# \end{equation}
# where $x[n]$ is input signal, and $\omega[n-m]$ represents the overlapping Kaiser window function with an adjustable shape factor $\beta$ that improves the resolution and reduces the spectral leakage close to the sidelobes of the signal. The coefficients of the Kaiser window are computed as:
# \begin{equation}
#     \omega[n]=\frac{I_{0}\left(\beta\sqrt{1-\left(\frac{n-N/2}{N/2}\right)^{2}}\right)}{I_{0}(\beta)}, 0 \leq n \leq N
# \end{equation}
#
# This dataset has a training set of 5,000 examples, and a test set of 1,000 examples.
#
# # Submission
#
# 1. **Coding checks (60 points)** - The code for your implementation should be in Python only. The name of the Main file should be main.ipynb or main.py. Please provide necessary comments in the code.
#
# 2. **Written Report (40 points)**: The report should be delivered as a separate pdf file, and it is recommended for you to use the NIPS template to structure your report. You may include comments in the Jupyter Notebook, however you will need to duplicate the results in the report. The report should describe your results, experimental setup and comparison between the results obtained
# from different setting of the algorithm and dataset.**Again, the questions in the Assignment PDF and here are the same (for the written report), we just put them in both places for convenience.**
#
#
# As such, you will submit, one member of your group will subit as a zip file on UBLearns, a ```.zip``` file that contains 3 things:
# - Your completed jupyter notebook.
# - Your written report.

# %%
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
## please add the essential libraries

# YOUR CODE HERE

# %% [markdown]
# ## Part 1. loading dataset
#
# We have splitted the dataset into training, validation and test. You can load every single folder to load dataset using keras ImageDataGenerator (10 points).

# %%
img_width, img_height = 224, 224
train_data_dir      = 'pictures/pictures/train'
validation_data_dir = 'pictures/pictures/val'
test_data_dir       = 'pictures/pictures/test'

epochs = 50
batch_size = 16

# # this is a generator that will read pictures found in
# # subfolers of 'data/train', and indefinitely generate
# # batches of augmented image data
datagen = ImageDataGenerator(rescale=1./255)

# Your Code HERE
train_generator = datagen.flow_from_directory(train_data_dir,batch_size=batch_size, target_size=(img_width,img_height))
valid_generator = datagen.flow_from_directory(validation_data_dir,batch_size=batch_size, target_size=(img_width,img_height))
test_generator  = datagen.flow_from_directory(test_data_dir,batch_size=batch_size, target_size=(img_width,img_height), shuffle=False) 


# please print the number of samples in each folder
# Out:
# Found 4176 images belonging to 10 classes.
# Found 1392 images belonging to 10 classes.
# Found 1392 images belonging to 10 classes.

# %% [markdown]
# ## Part 2.1 - Build your Neural Network and Train
#
# Build a Convolutional Neural Network with 2 or 3 hidden layers without regularization methods, which includes Conv2D layer, activation Layer. please use training dataset and validation dataset for training processs, and plot the training process with Loss trend and accuracy trend (30 Points).
#
# ## Part 2.2 - Test
#
# Test your machine learning model on the testing set: After finishing all the above steps, fix your hyper-parameters(learning rate, number of neurons per layer) and model parameter and test your model’s performance on the testing set. This shows the effectiveness of your model’s generalization power gained by learning. For test dataset, the performance should be more than 80% (10 Points).

# %%
# build conv2D CNN model, be careful with softmax and output layers is 10
from keras.models import Sequential
from tensorflow import keras
from tensorflow.keras import layers

# define the input shape of Convolutional Neural Network
# Your Code HERE
input_shape = (img_width,img_height,3)

# define the Convolutional Neural Network
model = Sequential([
    layers.Conv2D(32, kernel_size=(3, 3), activation="relu", input_shape=input_shape, padding='same'),
    layers.MaxPool2D(pool_size=(2,2), strides=2),
    layers.Conv2D(64, kernel_size=(3, 3), activation="relu", padding='same'),
    layers.MaxPool2D(pool_size=(2,2), strides=2),
    layers.Flatten(),
    layers.Dense(10, activation="softmax"),
])
# Your Code HERE
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_25 (Conv2D)          (None, 224, 224, 32)      896
#
#  max_pooling2d_12 (MaxPoolin  (None, 112, 112, 32)     0
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 112, 112, 64)      18496
#
#  max_pooling2d_13 (MaxPoolin  (None, 56, 56, 64)       0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 200704)            0
#
#  dense_11 (Dense)            (None, 10)                2007050
#
# =================================================================
# Total params: 2,026,442
# Trainable params: 2,026,442
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model and training including the files of compile and fit
#Your code 
model.compile(
    loss='categorical_crossentropy',
    metrics=['accuracy'],
    optimizer="adam"
)

#Train the model with training and validation set
model.fit(
    x=train_generator,
    epochs=epochs,
    validation_data=valid_generator
)
# Out:
# Epoch 1/50
# 261/261 [==============================] - 188s 720ms/step - loss: 0.0201 - accuracy: 0.9940 - val_loss: 1.3904 - val_accuracy: 0.8032
# Epoch 2/50
# 261/261 [==============================] - 185s 709ms/step - loss: 0.0040 - accuracy: 0.9988 - val_loss: 1.5704 - val_accuracy: 0.8075
# Epoch 3/50
# 261/261 [==============================] - 176s 676ms/step - loss: 9.2884e-06 - accuracy: 1.0000 - val_loss: 1.5540 - val_accuracy: 0.8053
# Epoch 4/50
# 261/261 [==============================] - 189s 725ms/step - loss: 3.8033e-06 - accuracy: 1.0000 - val_loss: 1.5622 - val_accuracy: 0.8075
# Epoch 5/50
# 261/261 [==============================] - 167s 638ms/step - loss: 1.6686e-06 - accuracy: 1.0000 - val_loss: 1.5518 - val_accuracy: 0.8147
# Epoch 6/50
# 261/261 [==============================] - 149s 570ms/step - loss: 7.9969e-07 - accuracy: 1.0000 - val_loss: 1.5419 - val_accuracy: 0.8147
# Epoch 7/50
# 261/261 [==============================] - 167s 639ms/step - loss: 4.6870e-07 - accuracy: 1.0000 - val_loss: 1.5403 - val_accuracy: 0.8125
# Epoch 8/50
# 261/261 [==============================] - 178s 682ms/step - loss: 3.1298e-07 - accuracy: 1.0000 - val_loss: 1.5476 - val_accuracy: 0.8125
# Epoch 9/50
# 261/261 [==============================] - 187s 716ms/step - loss: 2.1501e-07 - accuracy: 1.0000 - val_loss: 1.5419 - val_accuracy: 0.8096
# Epoch 10/50
# 261/261 [==============================] - 180s 691ms/step - loss: 1.6057e-07 - accuracy: 1.0000 - val_loss: 1.5453 - val_accuracy: 0.8111
# Epoch 11/50
# 261/261 [==============================] - 172s 659ms/step - loss: 1.2215e-07 - accuracy: 1.0000 - val_loss: 1.5374 - val_accuracy: 0.8096
# Epoch 12/50
# 261/261 [==============================] - 180s 690ms/step - loss: 9.6058e-08 - accuracy: 1.0000 - val_loss: 1.5399 - val_accuracy: 0.8096
# Epoch 13/50
# 261/261 [==============================] - 165s 634ms/step - loss: 7.6618e-08 - accuracy: 1.0000 - val_loss: 1.5378 - val_accuracy: 0.8103
# Epoch 14/50
# 261/261 [==============================] - 180s 690ms/step - loss: 6.2031e-08 - accuracy: 1.0000 - val_loss: 1.5402 - val_accuracy: 0.8096
# Epoch 15/50
# 261/261 [==============================] - 171s 654ms/step - loss: 5.0898e-08 - accuracy: 1.0000 - val_loss: 1.5378 - val_accuracy: 0.8125
# Epoch 16/50
# 261/261 [==============================] - 4025s 15s/step - loss: 4.1021e-08 - accuracy: 1.0000 - val_loss: 1.5412 - val_accuracy: 0.8147
# Epoch 17/50
# 261/261 [==============================] - 286s 1s/step - loss: 3.3599e-08 - accuracy: 1.0000 - val_loss: 1.5399 - val_accuracy: 0.8147
# Epoch 18/50
# 261/261 [==============================] - 317s 1s/step - loss: 2.7718e-08 - accuracy: 1.0000 - val_loss: 1.5460 - val_accuracy: 0.8111
# Epoch 19/50
# 261/261 [==============================] - 267s 1s/step - loss: 2.3122e-08 - accuracy: 1.0000 - val_loss: 1.5443 - val_accuracy: 0.8161
# Epoch 20/50
# 261/261 [==============================] - 243s 929ms/step - loss: 1.9069e-08 - accuracy: 1.0000 - val_loss: 1.5458 - val_accuracy: 0.8168
# Epoch 21/50
# 261/261 [==============================] - 248s 948ms/step - loss: 1.5272e-08 - accuracy: 1.0000 - val_loss: 1.5536 - val_accuracy: 0.8147
# Epoch 22/50
# 261/261 [==============================] - 258s 987ms/step - loss: 1.3046e-08 - accuracy: 1.0000 - val_loss: 1.5607 - val_accuracy: 0.8168
# Epoch 23/50
# 261/261 [==============================] - 257s 983ms/step - loss: 1.0505e-08 - accuracy: 1.0000 - val_loss: 1.5691 - val_accuracy: 0.8154
# Epoch 24/50
# 261/261 [==============================] - 259s 989ms/step - loss: 8.5639e-09 - accuracy: 1.0000 - val_loss: 1.5564 - val_accuracy: 0.8175
# Epoch 25/50
# 261/261 [==============================] - 232s 888ms/step - loss: 7.2793e-09 - accuracy: 1.0000 - val_loss: 1.5743 - val_accuracy: 0.8190
# Epoch 26/50
# 261/261 [==============================] - 216s 825ms/step - loss: 6.8226e-09 - accuracy: 1.0000 - val_loss: 1.6073 - val_accuracy: 0.8132
# Epoch 27/50
# 261/261 [==============================] - 183s 702ms/step - loss: 5.6236e-09 - accuracy: 1.0000 - val_loss: 1.5927 - val_accuracy: 0.8190
# Epoch 28/50
# 261/261 [==============================] - 174s 666ms/step - loss: 5.4238e-09 - accuracy: 1.0000 - val_loss: 1.6617 - val_accuracy: 0.8147
# Epoch 29/50
# 261/261 [==============================] - 206s 789ms/step - loss: 4.3676e-09 - accuracy: 1.0000 - val_loss: 1.6910 - val_accuracy: 0.8168
# Epoch 30/50
# 261/261 [==============================] - 194s 743ms/step - loss: 5.2240e-09 - accuracy: 1.0000 - val_loss: 1.8470 - val_accuracy: 0.7989
# Epoch 31/50
# 261/261 [==============================] - 177s 677ms/step - loss: 0.1905 - accuracy: 0.9691 - val_loss: 1.2265 - val_accuracy: 0.7823
# Epoch 32/50
# 261/261 [==============================] - 196s 751ms/step - loss: 0.0024 - accuracy: 0.9998 - val_loss: 1.1754 - val_accuracy: 0.7960
# Epoch 33/50
# 261/261 [==============================] - 183s 702ms/step - loss: 1.2158e-04 - accuracy: 1.0000 - val_loss: 1.2120 - val_accuracy: 0.7989
# Epoch 34/50
# 261/261 [==============================] - 172s 659ms/step - loss: 7.4990e-05 - accuracy: 1.0000 - val_loss: 1.2429 - val_accuracy: 0.8024
# Epoch 35/50
# 261/261 [==============================] - 175s 669ms/step - loss: 5.2361e-05 - accuracy: 1.0000 - val_loss: 1.2711 - val_accuracy: 0.8032
# Epoch 36/50
# 261/261 [==============================] - 168s 644ms/step - loss: 3.8885e-05 - accuracy: 1.0000 - val_loss: 1.2950 - val_accuracy: 0.8039
# Epoch 37/50
# 261/261 [==============================] - 168s 645ms/step - loss: 2.9973e-05 - accuracy: 1.0000 - val_loss: 1.3173 - val_accuracy: 0.8053
# Epoch 38/50
# 261/261 [==============================] - 167s 639ms/step - loss: 2.3747e-05 - accuracy: 1.0000 - val_loss: 1.3368 - val_accuracy: 0.8060
# Epoch 39/50
# 261/261 [==============================] - 168s 645ms/step - loss: 1.9142e-05 - accuracy: 1.0000 - val_loss: 1.3554 - val_accuracy: 0.8032
# Epoch 40/50
# 261/261 [==============================] - 180s 690ms/step - loss: 1.5655e-05 - accuracy: 1.0000 - val_loss: 1.3737 - val_accuracy: 0.8032
# Epoch 41/50
# 261/261 [==============================] - 175s 670ms/step - loss: 1.2921e-05 - accuracy: 1.0000 - val_loss: 1.3916 - val_accuracy: 0.8024
# Epoch 42/50
# 261/261 [==============================] - 174s 667ms/step - loss: 1.0757e-05 - accuracy: 1.0000 - val_loss: 1.4080 - val_accuracy: 0.8024
# Epoch 43/50
# 261/261 [==============================] - 175s 668ms/step - loss: 9.0095e-06 - accuracy: 1.0000 - val_loss: 1.4248 - val_accuracy: 0.8024
# Epoch 44/50
# 261/261 [==============================] - 180s 688ms/step - loss: 7.5876e-06 - accuracy: 1.0000 - val_loss: 1.4409 - val_accuracy: 0.8024
# Epoch 45/50
# 261/261 [==============================] - 190s 730ms/step - loss: 6.4285e-06 - accuracy: 1.0000 - val_loss: 1.4565 - val_accuracy: 0.8024
# Epoch 46/50
# 261/261 [==============================] - 199s 761ms/step - loss: 5.4555e-06 - accuracy: 1.0000 - val_loss: 1.4712 - val_accuracy: 0.8017
# Epoch 47/50
# 261/261 [==============================] - 199s 763ms/step - loss: 4.6421e-06 - accuracy: 1.0000 - val_loss: 1.4880 - val_accuracy: 0.8017
# Epoch 48/50
# 261/261 [==============================] - 190s 727ms/step - loss: 3.9620e-06 - accuracy: 1.0000 - val_loss: 1.5031 - val_accuracy: 0.8010
# Epoch 49/50
# 261/261 [==============================] - 188s 721ms/step - loss: 3.3950e-06 - accuracy: 1.0000 - val_loss: 1.5185 - val_accuracy: 0.8003
# Epoch 50/50
# 261/261 [==============================] - 187s 716ms/step - loss: 2.9175e-06 - accuracy: 1.0000 - val_loss: 1.5338 - val_accuracy: 0.8003

# %% [markdown]
# %Test

# %%
loss=model.history.__dict__['history']['loss']
accuracy=model.history.__dict__['history']['accuracy']

from matplotlib import pyplot as plt 

plt.plot(loss,accuracy)
plt.title('Training Process')
plt.xlabel('Loss Function')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
# Test the model on a testing dataset
# Your Code HERE
model.fit(x=test_generator,epochs=epochs)
# Out:
# Epoch 1/50
# 87/87 [==============================] - 55s 628ms/step - loss: 2.2720 - accuracy: 0.4138
# Epoch 2/50
# 87/87 [==============================] - 51s 591ms/step - loss: 0.3187 - accuracy: 0.9325
# Epoch 3/50
# 87/87 [==============================] - 52s 599ms/step - loss: 0.0120 - accuracy: 0.9971
# Epoch 4/50
# 87/87 [==============================] - 57s 658ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 5/50
# 87/87 [==============================] - 54s 619ms/step - loss: 4.6614e-04 - accuracy: 1.0000
# Epoch 6/50
# 87/87 [==============================] - 57s 653ms/step - loss: 2.8993e-04 - accuracy: 1.0000
# Epoch 7/50
# 87/87 [==============================] - 57s 652ms/step - loss: 2.0354e-04 - accuracy: 1.0000
# Epoch 8/50
# 87/87 [==============================] - 56s 637ms/step - loss: 1.4892e-04 - accuracy: 1.0000
# Epoch 9/50
# 87/87 [==============================] - 52s 603ms/step - loss: 1.0473e-04 - accuracy: 1.0000
# Epoch 10/50
# 87/87 [==============================] - 53s 613ms/step - loss: 4.8927e-05 - accuracy: 1.0000
# Epoch 11/50
# 87/87 [==============================] - 53s 604ms/step - loss: 2.4205e-05 - accuracy: 1.0000
# Epoch 12/50
# 87/87 [==============================] - 51s 591ms/step - loss: 1.4597e-05 - accuracy: 1.0000
# Epoch 13/50
# 87/87 [==============================] - 56s 645ms/step - loss: 1.0196e-05 - accuracy: 1.0000
# Epoch 14/50
# 87/87 [==============================] - 56s 641ms/step - loss: 7.4707e-06 - accuracy: 1.0000
# Epoch 15/50
# 87/87 [==============================] - 48s 546ms/step - loss: 5.7322e-06 - accuracy: 1.0000
# Epoch 16/50
# 87/87 [==============================] - 54s 622ms/step - loss: 4.5624e-06 - accuracy: 1.0000
# Epoch 17/50
# 87/87 [==============================] - 60s 686ms/step - loss: 3.7284e-06 - accuracy: 1.0000
# Epoch 18/50
# 87/87 [==============================] - 65s 753ms/step - loss: 3.1094e-06 - accuracy: 1.0000
# Epoch 19/50
# 87/87 [==============================] - 60s 688ms/step - loss: 2.6608e-06 - accuracy: 1.0000
# Epoch 20/50
# 87/87 [==============================] - 63s 716ms/step - loss: 2.2711e-06 - accuracy: 1.0000
# Epoch 21/50
# 87/87 [==============================] - 61s 704ms/step - loss: 1.9560e-06 - accuracy: 1.0000
# Epoch 22/50
# 87/87 [==============================] - 74s 852ms/step - loss: 1.7087e-06 - accuracy: 1.0000
# Epoch 23/50
# 87/87 [==============================] - 77s 881ms/step - loss: 1.4904e-06 - accuracy: 1.0000
# Epoch 24/50
# 87/87 [==============================] - 96s 1s/step - loss: 1.3297e-06 - accuracy: 1.0000
# Epoch 25/50
# 87/87 [==============================] - 60s 679ms/step - loss: 1.1757e-06 - accuracy: 1.0000
# Epoch 26/50
# 87/87 [==============================] - 57s 655ms/step - loss: 1.0528e-06 - accuracy: 1.0000
# Epoch 27/50
# 87/87 [==============================] - 48s 548ms/step - loss: 9.4734e-07 - accuracy: 1.0000
# Epoch 28/50
# 87/87 [==============================] - 46s 526ms/step - loss: 8.5579e-07 - accuracy: 1.0000
# Epoch 29/50
# 87/87 [==============================] - 46s 525ms/step - loss: 7.7400e-07 - accuracy: 1.0000
# Epoch 30/50
# 87/87 [==============================] - 46s 532ms/step - loss: 7.0575e-07 - accuracy: 1.0000
# Epoch 31/50
# 87/87 [==============================] - 47s 535ms/step - loss: 6.3887e-07 - accuracy: 1.0000
# Epoch 32/50
# 87/87 [==============================] - 47s 539ms/step - loss: 5.8423e-07 - accuracy: 1.0000
# Epoch 33/50
# 87/87 [==============================] - 47s 541ms/step - loss: 5.3524e-07 - accuracy: 1.0000
# Epoch 34/50
# 87/87 [==============================] - 46s 529ms/step - loss: 4.9157e-07 - accuracy: 1.0000
# Epoch 35/50
# 87/87 [==============================] - 47s 535ms/step - loss: 4.5209e-07 - accuracy: 1.0000
# Epoch 36/50
# 87/87 [==============================] - 46s 534ms/step - loss: 4.1972e-07 - accuracy: 1.0000
# Epoch 37/50
# 87/87 [==============================] - 52s 595ms/step - loss: 3.8692e-07 - accuracy: 1.0000
# Epoch 38/50
# 87/87 [==============================] - 60s 691ms/step - loss: 3.5412e-07 - accuracy: 1.0000
# Epoch 39/50
# 87/87 [==============================] - 56s 646ms/step - loss: 3.2834e-07 - accuracy: 1.0000
# Epoch 40/50
# 87/87 [==============================] - 47s 536ms/step - loss: 3.0436e-07 - accuracy: 1.0000
# Epoch 41/50
# 87/87 [==============================] - 46s 534ms/step - loss: 2.8561e-07 - accuracy: 1.0000
# Epoch 42/50
# 87/87 [==============================] - 46s 534ms/step - loss: 2.6274e-07 - accuracy: 1.0000
# Epoch 43/50
# 87/87 [==============================] - 47s 535ms/step - loss: 2.4527e-07 - accuracy: 1.0000
# Epoch 44/50
# 87/87 [==============================] - 47s 541ms/step - loss: 2.2634e-07 - accuracy: 1.0000
# Epoch 45/50
# 87/87 [==============================] - 47s 543ms/step - loss: 2.1093e-07 - accuracy: 1.0000
# Epoch 46/50
# 87/87 [==============================] - 48s 555ms/step - loss: 1.9783e-07 - accuracy: 1.0000
# Epoch 47/50
# 87/87 [==============================] - 53s 607ms/step - loss: 1.8344e-07 - accuracy: 1.0000
# Epoch 48/50
# 87/87 [==============================] - 53s 602ms/step - loss: 1.7256e-07 - accuracy: 1.0000
# Epoch 49/50
# 87/87 [==============================] - 55s 635ms/step - loss: 1.5963e-07 - accuracy: 1.0000
# Epoch 50/50
# 87/87 [==============================] - 53s 607ms/step - loss: 1.4918e-07 - accuracy: 1.0000

# %% [markdown]
# ## Part 2.3 - L1 Regularization. Please add L1 regularization setting in your Conv2D layer. Then, train your new model separately, and plot the training process including loss and accuracy. (10 points)

# %%
# please redefine your model with setting the L1 Regularization in the layer of Conv 2D

# Your code HERE

# %% [markdown]
# ## Part 2.4 - L2 Regularization. Please add L2 regularization setting in your Conv2D layer. Then, train your new model separately, and plot the training process including loss and accuracy. (10 points)

# %%
#please redefine your model and set the L2 Regularization in the layer of Conv 2D

# Your code HERE

# %% [markdown]
# ## Part3 - ** only for 574 students **.
# 1. Fine tune the well pre-trained model, Resnet 50, with different freeze layers.
# First,  load pre-trained resnet 50 from library.
# Second, Fine-tune the model to fit our project, 10-classes.
# Third,  freeze different layers, plot different training process with different frozen layers (at least three different layers).

# %%
# load pre-trained resnet 50 from libarary
# your Code HERE


# Fine-tune the model to fit our project  
# your Code HERE


# define the freeze layers 
# your Code HERE


# Please compile the new model
#model.compile()


#Train the model with training and validation set
#model.fit()
