# %% [markdown]
# # Programming Assignment 5 - Build your own Conventional Neural Network
#
# After completing this project, you will be able to do the following:
#
# - Build neural network conveniently.
# - Configure with different regularization methods: Dropout, l1 or l2 regulation.
#
# - **574 Only**: Fine tune pre-trained model to build your own projects.
#
# # Dataset
#
# This dataset is provided by our current research project, which utilize 20 kHz acoustic sensing to sense ASL gestures. All the 10 ASL words perform by 5 subjects. All images are generated by using the short-time Fourier transform (STFT) to calculate a spectrogram as the feature representation of the reflected near-ultrasound waves. Based on the Doppler effect, sign language gestures, including both hands and arms, will cause phase and frequency changes of the reflected sonic wave. The spectrogram contains information in both frequency and time domains. The spectrogram is also defined as the Power Spectral Density of the function:
# \begin{equation}
#     \textrm{spectrogram}\{x(t)\}(\tau,\omega)\equiv |X(\tau,\omega)|^{2}= \left| \sum^{\infty}_{n=-\infty}x[n]\omega[n-m]e^{-j\omega n}\right|^{2}
# \end{equation}
# where $x[n]$ is input signal, and $\omega[n-m]$ represents the overlapping Kaiser window function with an adjustable shape factor $\beta$ that improves the resolution and reduces the spectral leakage close to the sidelobes of the signal. The coefficients of the Kaiser window are computed as:
# \begin{equation}
#     \omega[n]=\frac{I_{0}\left(\beta\sqrt{1-\left(\frac{n-N/2}{N/2}\right)^{2}}\right)}{I_{0}(\beta)}, 0 \leq n \leq N
# \end{equation}
#
# This dataset has a training set of 5,000 examples, and a test set of 1,000 examples.
#
# # Submission
#
# 1. **Coding checks (60 points)** - The code for your implementation should be in Python only. The name of the Main file should be main.ipynb or main.py. Please provide necessary comments in the code.
#
# 2. **Written Report (40 points)**: The report should be delivered as a separate pdf file, and it is recommended for you to use the NIPS template to structure your report. You may include comments in the Jupyter Notebook, however you will need to duplicate the results in the report. The report should describe your results, experimental setup and comparison between the results obtained
# from different setting of the algorithm and dataset.**Again, the questions in the Assignment PDF and here are the same (for the written report), we just put them in both places for convenience.**
#
#
# As such, you will submit, one member of your group will subit as a zip file on UBLearns, a ```.zip``` file that contains 3 things:
# - Your completed jupyter notebook.
# - Your written report.

# %%
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
## please add the essential libraries

# YOUR CODE HERE

# %% [markdown]
# ## Part 1. loading dataset
#
# We have splitted the dataset into training, validation and test. You can load every single folder to load dataset using keras ImageDataGenerator (10 points).

# %%
img_width, img_height = 224, 224
train_data_dir      = 'pictures/pictures/train'
validation_data_dir = 'pictures/pictures/val'
test_data_dir       = 'pictures/pictures/test'

epochs = 50
batch_size = 16

# # this is a generator that will read pictures found in
# # subfolers of 'data/train', and indefinitely generate
# # batches of augmented image data
datagen = ImageDataGenerator(rescale=1./255)

# Your Code HERE
train_generator = datagen.flow_from_directory(train_data_dir,batch_size=batch_size, target_size=(img_width,img_height))
valid_generator = datagen.flow_from_directory(validation_data_dir,batch_size=batch_size, target_size=(img_width,img_height))
test_generator  = datagen.flow_from_directory(test_data_dir,batch_size=batch_size, target_size=(img_width,img_height), shuffle=False) 


# please print the number of samples in each folder
# Out:
# Found 4176 images belonging to 10 classes.
# Found 1392 images belonging to 10 classes.
# Found 1392 images belonging to 10 classes.

# %% [markdown]
# ## Part 2.1 - Build your Neural Network and Train
#
# Build a Convolutional Neural Network with 2 or 3 hidden layers without regularization methods, which includes Conv2D layer, activation Layer. please use training dataset and validation dataset for training processs, and plot the training process with Loss trend and accuracy trend (30 Points).
#
# ## Part 2.2 - Test
#
# Test your machine learning model on the testing set: After finishing all the above steps, fix your hyper-parameters(learning rate, number of neurons per layer) and model parameter and test your model’s performance on the testing set. This shows the effectiveness of your model’s generalization power gained by learning. For test dataset, the performance should be more than 80% (10 Points).

# %%
# build conv2D CNN model, be careful with softmax and output layers is 10
from keras.models import Sequential
from tensorflow import keras
from tensorflow.keras import layers

# define the input shape of Convolutional Neural Network
# Your Code HERE
input_shape = (img_width,img_height,3)

# define the Convolutional Neural Network
model = Sequential([
    layers.Conv2D(3, kernel_size=(3, 3), activation="relu", input_shape=input_shape, padding='same', batch_size=batch_size),
    layers.MaxPool2D(pool_size=(2,2), strides=2),
    layers.Conv2D(6, kernel_size=(3, 3), activation="relu",  padding='same'),
    layers.MaxPool2D(pool_size=(2,2), strides=2),
    layers.Conv2D(12, kernel_size=(3, 3), activation="relu",  padding='same'),
    layers.MaxPool2D(pool_size=(2,2), strides=2),   
    layers.Flatten(),
    layers.Dropout(0.75),
    layers.Dense(10, activation="softmax"),
])
# Your Code HERE
model.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_37 (Conv2D)          (16, 224, 224, 3)         84
#
#  max_pooling2d_25 (MaxPoolin  (16, 112, 112, 3)        0
#  g2D)
#
#  conv2d_38 (Conv2D)          (16, 112, 112, 6)         168
#
#  max_pooling2d_26 (MaxPoolin  (16, 56, 56, 6)          0
#  g2D)
#
#  conv2d_39 (Conv2D)          (16, 56, 56, 12)          660
#
#  max_pooling2d_27 (MaxPoolin  (16, 28, 28, 12)         0
#  g2D)
#
#  flatten_20 (Flatten)        (16, 9408)                0
#
#  dropout_22 (Dropout)        (16, 9408)                0
#
#  dense_20 (Dense)            (16, 10)                  94090
#
# =================================================================
# Total params: 95,002
# Trainable params: 95,002
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model and training including the files of compile and fit
#Your code 
model.compile(
    loss='categorical_crossentropy',
    metrics=['accuracy'],
    optimizer="adam"
)

#Train the model with training and validation set
model.fit(
    x=train_generator,
    epochs=epochs,
    validation_data=valid_generator
)
# Out:
# Epoch 1/50
# 261/261 [==============================] - 75s 286ms/step - loss: 0.9796 - accuracy: 0.6592 - val_loss: 0.7144 - val_accuracy: 0.8175
# Epoch 2/50
# 261/261 [==============================] - 66s 252ms/step - loss: 0.2892 - accuracy: 0.9016 - val_loss: 0.7363 - val_accuracy: 0.8175
# Epoch 3/50
# 261/261 [==============================] - 67s 258ms/step - loss: 0.1866 - accuracy: 0.9409 - val_loss: 0.7728 - val_accuracy: 0.8211
# Epoch 4/50
# 261/261 [==============================] - 69s 264ms/step - loss: 0.1326 - accuracy: 0.9581 - val_loss: 0.8729 - val_accuracy: 0.8032
# Epoch 5/50
# 261/261 [==============================] - 65s 247ms/step - loss: 0.1122 - accuracy: 0.9619 - val_loss: 0.7494 - val_accuracy: 0.8384
# Epoch 6/50
# 261/261 [==============================] - 64s 246ms/step - loss: 0.0939 - accuracy: 0.9682 - val_loss: 0.9900 - val_accuracy: 0.7924
# Epoch 7/50
# 261/261 [==============================] - 63s 242ms/step - loss: 0.0839 - accuracy: 0.9703 - val_loss: 0.8058 - val_accuracy: 0.8376
# Epoch 8/50
# 261/261 [==============================] - 63s 243ms/step - loss: 0.0747 - accuracy: 0.9739 - val_loss: 0.8494 - val_accuracy: 0.8348
# Epoch 9/50
# 261/261 [==============================] - 68s 261ms/step - loss: 0.0728 - accuracy: 0.9737 - val_loss: 0.9620 - val_accuracy: 0.8297
# Epoch 10/50
# 261/261 [==============================] - 63s 240ms/step - loss: 0.0623 - accuracy: 0.9775 - val_loss: 1.0100 - val_accuracy: 0.8261
# Epoch 11/50
# 261/261 [==============================] - 61s 234ms/step - loss: 0.0546 - accuracy: 0.9811 - val_loss: 1.0877 - val_accuracy: 0.8039
# Epoch 12/50
# 261/261 [==============================] - 63s 240ms/step - loss: 0.0567 - accuracy: 0.9816 - val_loss: 0.8794 - val_accuracy: 0.8247
# Epoch 13/50
# 261/261 [==============================] - 63s 239ms/step - loss: 0.0490 - accuracy: 0.9847 - val_loss: 1.2025 - val_accuracy: 0.8168
# Epoch 14/50
# 261/261 [==============================] - 62s 237ms/step - loss: 0.0492 - accuracy: 0.9844 - val_loss: 1.0168 - val_accuracy: 0.8269
# Epoch 15/50
# 261/261 [==============================] - 63s 240ms/step - loss: 0.0555 - accuracy: 0.9818 - val_loss: 0.8179 - val_accuracy: 0.8269
# Epoch 16/50
# 261/261 [==============================] - 63s 240ms/step - loss: 0.0424 - accuracy: 0.9847 - val_loss: 1.0511 - val_accuracy: 0.8168
# Epoch 17/50
# 261/261 [==============================] - 63s 243ms/step - loss: 0.0387 - accuracy: 0.9856 - val_loss: 1.0937 - val_accuracy: 0.8039
# Epoch 18/50
# 261/261 [==============================] - 63s 240ms/step - loss: 0.0427 - accuracy: 0.9852 - val_loss: 1.0471 - val_accuracy: 0.8218
# Epoch 19/50
# 261/261 [==============================] - 62s 238ms/step - loss: 0.0335 - accuracy: 0.9885 - val_loss: 1.0160 - val_accuracy: 0.8355
# Epoch 20/50
# 261/261 [==============================] - 63s 241ms/step - loss: 0.0350 - accuracy: 0.9885 - val_loss: 0.9553 - val_accuracy: 0.8376
# Epoch 21/50
# 261/261 [==============================] - 62s 235ms/step - loss: 0.0320 - accuracy: 0.9883 - val_loss: 0.9242 - val_accuracy: 0.8405
# Epoch 22/50
# 261/261 [==============================] - 64s 244ms/step - loss: 0.0338 - accuracy: 0.9899 - val_loss: 1.0828 - val_accuracy: 0.8218
# Epoch 23/50
# 261/261 [==============================] - 63s 240ms/step - loss: 0.0323 - accuracy: 0.9892 - val_loss: 1.1818 - val_accuracy: 0.8204
# Epoch 24/50
# 261/261 [==============================] - 64s 246ms/step - loss: 0.0236 - accuracy: 0.9926 - val_loss: 1.1805 - val_accuracy: 0.8290
# Epoch 25/50
# 261/261 [==============================] - 62s 236ms/step - loss: 0.0247 - accuracy: 0.9919 - val_loss: 1.1808 - val_accuracy: 0.8326
# Epoch 26/50
# 261/261 [==============================] - 61s 235ms/step - loss: 0.0390 - accuracy: 0.9875 - val_loss: 1.0679 - val_accuracy: 0.8290
# Epoch 27/50
# 261/261 [==============================] - 62s 238ms/step - loss: 0.0271 - accuracy: 0.9902 - val_loss: 1.0243 - val_accuracy: 0.8103
# Epoch 28/50
# 261/261 [==============================] - 63s 240ms/step - loss: 0.0318 - accuracy: 0.9897 - val_loss: 1.2740 - val_accuracy: 0.8111
# Epoch 29/50
# 261/261 [==============================] - 62s 237ms/step - loss: 0.0219 - accuracy: 0.9923 - val_loss: 1.4134 - val_accuracy: 0.8319
# Epoch 30/50
# 261/261 [==============================] - 62s 238ms/step - loss: 0.0366 - accuracy: 0.9873 - val_loss: 1.2312 - val_accuracy: 0.8082
# Epoch 31/50
# 261/261 [==============================] - 63s 240ms/step - loss: 0.0278 - accuracy: 0.9921 - val_loss: 1.1837 - val_accuracy: 0.8111
# Epoch 32/50
# 261/261 [==============================] - 62s 239ms/step - loss: 0.0267 - accuracy: 0.9911 - val_loss: 1.1985 - val_accuracy: 0.8068
# Epoch 33/50
# 261/261 [==============================] - 61s 235ms/step - loss: 0.0183 - accuracy: 0.9947 - val_loss: 1.3219 - val_accuracy: 0.8068
# Epoch 34/50
# 261/261 [==============================] - 62s 238ms/step - loss: 0.0249 - accuracy: 0.9897 - val_loss: 1.1480 - val_accuracy: 0.8226
# Epoch 35/50
# 261/261 [==============================] - 62s 236ms/step - loss: 0.0291 - accuracy: 0.9911 - val_loss: 1.2392 - val_accuracy: 0.8276
# Epoch 36/50
# 261/261 [==============================] - 62s 236ms/step - loss: 0.0267 - accuracy: 0.9902 - val_loss: 1.2185 - val_accuracy: 0.8132
# Epoch 37/50
# 261/261 [==============================] - 61s 235ms/step - loss: 0.0222 - accuracy: 0.9933 - val_loss: 1.2734 - val_accuracy: 0.8118
# Epoch 38/50
# 261/261 [==============================] - 62s 236ms/step - loss: 0.0241 - accuracy: 0.9914 - val_loss: 1.1637 - val_accuracy: 0.8168
# Epoch 39/50
# 261/261 [==============================] - 62s 239ms/step - loss: 0.0153 - accuracy: 0.9950 - val_loss: 1.3788 - val_accuracy: 0.8405
# Epoch 40/50
# 261/261 [==============================] - 62s 236ms/step - loss: 0.0247 - accuracy: 0.9919 - val_loss: 1.4171 - val_accuracy: 0.8075
# Epoch 41/50
# 261/261 [==============================] - 61s 234ms/step - loss: 0.0163 - accuracy: 0.9940 - val_loss: 1.3770 - val_accuracy: 0.8161
# Epoch 42/50
# 261/261 [==============================] - 62s 238ms/step - loss: 0.0156 - accuracy: 0.9955 - val_loss: 1.3700 - val_accuracy: 0.8118
# Epoch 43/50
# 261/261 [==============================] - 60s 231ms/step - loss: 0.0219 - accuracy: 0.9923 - val_loss: 1.3127 - val_accuracy: 0.8348
# Epoch 44/50
# 261/261 [==============================] - 61s 235ms/step - loss: 0.0208 - accuracy: 0.9931 - val_loss: 1.2137 - val_accuracy: 0.8254
# Epoch 45/50
# 261/261 [==============================] - 62s 238ms/step - loss: 0.0223 - accuracy: 0.9926 - val_loss: 1.0956 - val_accuracy: 0.8032
# Epoch 46/50
# 261/261 [==============================] - 61s 234ms/step - loss: 0.0212 - accuracy: 0.9928 - val_loss: 1.1203 - val_accuracy: 0.8053
# Epoch 47/50
# 261/261 [==============================] - 61s 234ms/step - loss: 0.0141 - accuracy: 0.9957 - val_loss: 1.6641 - val_accuracy: 0.8319
# Epoch 48/50
# 261/261 [==============================] - 61s 233ms/step - loss: 0.0204 - accuracy: 0.9940 - val_loss: 1.2661 - val_accuracy: 0.8161
# Epoch 49/50
# 261/261 [==============================] - 61s 234ms/step - loss: 0.0221 - accuracy: 0.9928 - val_loss: 1.1947 - val_accuracy: 0.8024
# Epoch 50/50
# 261/261 [==============================] - 62s 237ms/step - loss: 0.0116 - accuracy: 0.9952 - val_loss: 1.3237 - val_accuracy: 0.8247

# %% [markdown]
# %Test

# %%
from matplotlib import pyplot as plt 

plt.plot(model.history.__dict__['history']['loss'], label='Training data')
plt.ylabel('Loss value')
plt.xlabel('No. epoch')
plt.show()

# Plot history: Accuracy
plt.plot(model.history.__dict__['history']['accuracy'], label='Training data')
plt.ylabel('%')
plt.xlabel('No. epoch')
plt.show()

# %%
# Test the model on a testing dataset
# Your Code HERE
score= model.evaluate(x=test_generator)
print("Test Loss", float(score[0]))
print("Test Accuracy", score[1]*100)
# Out:
# 87/87 [==============================] - 9s 101ms/step - loss: 1.5343 - accuracy: 0.8017
# Test Loss 1.5342868566513062
# Test Accuracy 80.17241358757019

# %% [markdown]
# ## Part 2.3 - L1 Regularization. Please add L1 regularization setting in your Conv2D layer. Then, train your new model separately, and plot the training process including loss and accuracy. (10 points)

# %%
# please redefine your model with setting the L1 Regularization in the layer of Conv 2D
from keras.models import Sequential
import tensorflow
from tensorflow import keras
from tensorflow.keras import layers

model1 = Sequential([
    layers.Conv2D(3, kernel_size=(3, 3), activation="relu", input_shape=input_shape, padding='same', batch_size=batch_size, kernel_regularizer=tensorflow.keras.regularizers.l1(0.01)),
    layers.MaxPool2D(pool_size=(2,2), strides=2),
    layers.Conv2D(6, kernel_size=(3, 3), activation="relu",  padding='same', kernel_regularizer=tensorflow.keras.regularizers.l1(0.01)),
    layers.MaxPool2D(pool_size=(2,2), strides=2),
    layers.Conv2D(12, kernel_size=(3, 3), activation="relu",  padding='same',kernel_regularizer=tensorflow.keras.regularizers.l1(0.01)),
    layers.MaxPool2D(pool_size=(2,2), strides=2),   
    layers.Flatten(),
    layers.Dense(10, activation="softmax"),
])

# Your Code HERE
model1.compile(
    loss='categorical_crossentropy',
    metrics=['accuracy'],
    optimizer="adam"
)

#Train the model with training and validation set
model1.fit(
    x=train_generator,
    epochs=epochs,
    validation_data=valid_generator
)
# Out:
# Epoch 1/50
# 261/261 [==============================] - 61s 230ms/step - loss: 1.2917 - accuracy: 0.7596 - val_loss: 1.1845 - val_accuracy: 0.7924
# Epoch 2/50
# 261/261 [==============================] - 62s 235ms/step - loss: 0.3833 - accuracy: 0.9823 - val_loss: 1.0423 - val_accuracy: 0.8168
# Epoch 3/50
# 261/261 [==============================] - 63s 241ms/step - loss: 0.2576 - accuracy: 0.9976 - val_loss: 1.1097 - val_accuracy: 0.8348
# Epoch 4/50
# 261/261 [==============================] - 61s 235ms/step - loss: 0.2062 - accuracy: 0.9986 - val_loss: 1.0440 - val_accuracy: 0.8254
# Epoch 5/50
# 261/261 [==============================] - 60s 231ms/step - loss: 0.1674 - accuracy: 1.0000 - val_loss: 0.9328 - val_accuracy: 0.8527
# Epoch 6/50
# 261/261 [==============================] - 69s 265ms/step - loss: 0.1465 - accuracy: 1.0000 - val_loss: 1.0635 - val_accuracy: 0.8297
# Epoch 7/50
# 261/261 [==============================] - 87s 332ms/step - loss: 0.1266 - accuracy: 1.0000 - val_loss: 0.9890 - val_accuracy: 0.8290
# Epoch 8/50
# 261/261 [==============================] - 69s 263ms/step - loss: 0.1377 - accuracy: 0.9947 - val_loss: 1.1169 - val_accuracy: 0.7974
# Epoch 9/50
# 261/261 [==============================] - 80s 306ms/step - loss: 0.1055 - accuracy: 1.0000 - val_loss: 0.9705 - val_accuracy: 0.8297
# Epoch 10/50
# 261/261 [==============================] - 55s 209ms/step - loss: 0.0955 - accuracy: 1.0000 - val_loss: 0.9791 - val_accuracy: 0.8348
# Epoch 11/50
# 261/261 [==============================] - 56s 216ms/step - loss: 0.1027 - accuracy: 0.9964 - val_loss: 1.0318 - val_accuracy: 0.8111
# Epoch 12/50
# 261/261 [==============================] - 57s 217ms/step - loss: 0.0985 - accuracy: 0.9971 - val_loss: 1.0433 - val_accuracy: 0.8326
# Epoch 13/50
# 261/261 [==============================] - 55s 210ms/step - loss: 0.0775 - accuracy: 1.0000 - val_loss: 0.9572 - val_accuracy: 0.8261
# Epoch 14/50
# 261/261 [==============================] - 54s 207ms/step - loss: 0.0734 - accuracy: 1.0000 - val_loss: 0.9468 - val_accuracy: 0.8269
# Epoch 15/50
# 261/261 [==============================] - 54s 207ms/step - loss: 0.0712 - accuracy: 1.0000 - val_loss: 0.9398 - val_accuracy: 0.8290
# Epoch 16/50
# 261/261 [==============================] - 54s 206ms/step - loss: 0.0693 - accuracy: 1.0000 - val_loss: 1.0097 - val_accuracy: 0.8103
# Epoch 17/50
# 261/261 [==============================] - 55s 209ms/step - loss: 0.0682 - accuracy: 1.0000 - val_loss: 0.9922 - val_accuracy: 0.8218
# Epoch 18/50
# 261/261 [==============================] - 57s 219ms/step - loss: 0.0663 - accuracy: 1.0000 - val_loss: 0.9780 - val_accuracy: 0.8247
# Epoch 19/50
# 261/261 [==============================] - 53s 201ms/step - loss: 0.0647 - accuracy: 1.0000 - val_loss: 0.9976 - val_accuracy: 0.8204
# Epoch 20/50
# 261/261 [==============================] - 50s 193ms/step - loss: 0.0633 - accuracy: 1.0000 - val_loss: 0.9721 - val_accuracy: 0.8247
# Epoch 21/50
# 261/261 [==============================] - 51s 196ms/step - loss: 0.0819 - accuracy: 0.9964 - val_loss: 1.2705 - val_accuracy: 0.8075
# Epoch 22/50
# 261/261 [==============================] - 52s 199ms/step - loss: 0.0735 - accuracy: 0.9974 - val_loss: 1.0147 - val_accuracy: 0.8111
# Epoch 23/50
# 261/261 [==============================] - 52s 200ms/step - loss: 0.0613 - accuracy: 1.0000 - val_loss: 0.9918 - val_accuracy: 0.8182
# Epoch 24/50
# 261/261 [==============================] - 52s 199ms/step - loss: 0.0596 - accuracy: 1.0000 - val_loss: 0.9940 - val_accuracy: 0.8017
# Epoch 25/50
# 261/261 [==============================] - 50s 191ms/step - loss: 0.0585 - accuracy: 1.0000 - val_loss: 0.9810 - val_accuracy: 0.8226
# Epoch 26/50
# 261/261 [==============================] - 52s 200ms/step - loss: 0.0575 - accuracy: 1.0000 - val_loss: 0.9691 - val_accuracy: 0.8247
# Epoch 27/50
# 261/261 [==============================] - 52s 197ms/step - loss: 0.0566 - accuracy: 1.0000 - val_loss: 1.0090 - val_accuracy: 0.8132
# Epoch 28/50
# 261/261 [==============================] - 53s 205ms/step - loss: 0.0562 - accuracy: 1.0000 - val_loss: 0.9998 - val_accuracy: 0.8175
# Epoch 29/50
# 261/261 [==============================] - 62s 237ms/step - loss: 0.0549 - accuracy: 1.0000 - val_loss: 0.9887 - val_accuracy: 0.8175
# Epoch 30/50
# 261/261 [==============================] - 63s 240ms/step - loss: 0.0543 - accuracy: 1.0000 - val_loss: 1.0340 - val_accuracy: 0.8218
# Epoch 31/50
# 261/261 [==============================] - 61s 235ms/step - loss: 0.0534 - accuracy: 1.0000 - val_loss: 0.9735 - val_accuracy: 0.8412
# Epoch 32/50
# 261/261 [==============================] - 62s 239ms/step - loss: 0.0528 - accuracy: 1.0000 - val_loss: 1.0617 - val_accuracy: 0.8341
# Epoch 33/50
# 261/261 [==============================] - 64s 244ms/step - loss: 0.0524 - accuracy: 1.0000 - val_loss: 0.9876 - val_accuracy: 0.8297
# Epoch 34/50
# 261/261 [==============================] - 62s 238ms/step - loss: 0.0513 - accuracy: 1.0000 - val_loss: 1.0289 - val_accuracy: 0.8204
# Epoch 35/50
# 261/261 [==============================] - 62s 237ms/step - loss: 0.0506 - accuracy: 1.0000 - val_loss: 0.9781 - val_accuracy: 0.8391
# Epoch 36/50
# 261/261 [==============================] - 62s 237ms/step - loss: 0.0502 - accuracy: 1.0000 - val_loss: 0.9955 - val_accuracy: 0.8305
# Epoch 37/50
# 261/261 [==============================] - 66s 251ms/step - loss: 0.0491 - accuracy: 1.0000 - val_loss: 0.9647 - val_accuracy: 0.8398
# Epoch 38/50
# 261/261 [==============================] - 56s 214ms/step - loss: 0.0484 - accuracy: 1.0000 - val_loss: 0.9794 - val_accuracy: 0.8484
# Epoch 39/50
# 261/261 [==============================] - 62s 239ms/step - loss: 0.0480 - accuracy: 1.0000 - val_loss: 0.9740 - val_accuracy: 0.8297
# Epoch 40/50
# 261/261 [==============================] - 60s 231ms/step - loss: 0.0473 - accuracy: 1.0000 - val_loss: 0.9469 - val_accuracy: 0.8376
# Epoch 41/50
# 261/261 [==============================] - 60s 230ms/step - loss: 0.0467 - accuracy: 1.0000 - val_loss: 0.9456 - val_accuracy: 0.8369
# Epoch 42/50
# 261/261 [==============================] - 61s 234ms/step - loss: 0.0461 - accuracy: 1.0000 - val_loss: 1.0198 - val_accuracy: 0.8455
# Epoch 43/50
# 261/261 [==============================] - 62s 236ms/step - loss: 0.0454 - accuracy: 1.0000 - val_loss: 0.9555 - val_accuracy: 0.8491
# Epoch 44/50
# 261/261 [==============================] - 62s 236ms/step - loss: 0.0449 - accuracy: 1.0000 - val_loss: 0.9577 - val_accuracy: 0.8491
# Epoch 45/50
# 261/261 [==============================] - 61s 233ms/step - loss: 0.0445 - accuracy: 1.0000 - val_loss: 0.9893 - val_accuracy: 0.8491
# Epoch 46/50
# 261/261 [==============================] - 62s 236ms/step - loss: 0.0438 - accuracy: 1.0000 - val_loss: 1.0049 - val_accuracy: 0.8261
# Epoch 47/50
# 261/261 [==============================] - 63s 241ms/step - loss: 0.0432 - accuracy: 1.0000 - val_loss: 0.9962 - val_accuracy: 0.8326
# Epoch 48/50
# 261/261 [==============================] - 65s 250ms/step - loss: 0.0425 - accuracy: 1.0000 - val_loss: 1.0026 - val_accuracy: 0.8412
# Epoch 49/50
# 261/261 [==============================] - 62s 236ms/step - loss: 0.0422 - accuracy: 1.0000 - val_loss: 1.0566 - val_accuracy: 0.8247
# Epoch 50/50
# 261/261 [==============================] - 62s 238ms/step - loss: 0.0417 - accuracy: 1.0000 - val_loss: 0.9898 - val_accuracy: 0.8333

# %%
loss=model1.history.__dict__['history']['loss']
accuracy=model1.history.__dict__['history']['accuracy']

from matplotlib import pyplot as plt 

plt.plot(model1.history.__dict__['history']['loss'], label='Training data')
plt.ylabel('Loss value')
plt.xlabel('No. epoch')
plt.show()

# Plot history: Accuracy
plt.plot(model1.history.__dict__['history']['accuracy'], label='Training data')
plt.ylabel('%')
plt.xlabel('No. epoch')
plt.show()

# %% [markdown]
# ## Part 2.4 - L2 Regularization. Please add L2 regularization setting in your Conv2D layer. Then, train your new model separately, and plot the training process including loss and accuracy. (10 points)

# %%
#please redefine your model and set the L2 Regularization in the layer of Conv 2D

# Your code HERE

# please redefine your model with setting the L1 Regularization in the layer of Conv 2D
from keras.models import Sequential
import tensorflow
from tensorflow import keras
from tensorflow.keras import layers

model2 = Sequential([
    layers.Conv2D(3, kernel_size=(3, 3), activation="relu", input_shape=input_shape, padding='same', batch_size=batch_size, kernel_regularizer=tensorflow.keras.regularizers.l2(0.01)),
    layers.MaxPool2D(pool_size=(2,2), strides=2),
    layers.Conv2D(6, kernel_size=(3, 3), activation="relu",  padding='same', kernel_regularizer=tensorflow.keras.regularizers.l2(0.01)),
    layers.MaxPool2D(pool_size=(2,2), strides=2),
    layers.Conv2D(12, kernel_size=(3, 3), activation="relu",  padding='same',kernel_regularizer=tensorflow.keras.regularizers.l2(0.01)),
    layers.MaxPool2D(pool_size=(2,2), strides=2),   
    layers.Flatten(),
    layers.Dense(10, activation="softmax"),
])

# Your Code HERE
model2.compile(
    loss='categorical_crossentropy',
    metrics=['accuracy'],
    optimizer="adam"
)

#Train the model with training and validation set
model2.fit(
    x=train_generator,
    epochs=epochs,
    validation_data=valid_generator
)
# Out:
# Epoch 1/50
# 261/261 [==============================] - 56s 210ms/step - loss: 0.8609 - accuracy: 0.7569 - val_loss: 1.0079 - val_accuracy: 0.7787
# Epoch 2/50
# 261/261 [==============================] - 62s 238ms/step - loss: 0.1298 - accuracy: 0.9878 - val_loss: 1.1558 - val_accuracy: 0.7974
# Epoch 3/50
# 261/261 [==============================] - 65s 249ms/step - loss: 0.0838 - accuracy: 0.9976 - val_loss: 1.1586 - val_accuracy: 0.8082
# Epoch 4/50
# 261/261 [==============================] - 67s 255ms/step - loss: 0.0697 - accuracy: 0.9986 - val_loss: 1.0986 - val_accuracy: 0.8348
# Epoch 5/50
# 261/261 [==============================] - 65s 250ms/step - loss: 0.0540 - accuracy: 1.0000 - val_loss: 1.1037 - val_accuracy: 0.8269
# Epoch 6/50
# 261/261 [==============================] - 69s 263ms/step - loss: 0.0458 - accuracy: 1.0000 - val_loss: 1.1395 - val_accuracy: 0.8226
# Epoch 7/50
# 261/261 [==============================] - 67s 255ms/step - loss: 0.0393 - accuracy: 1.0000 - val_loss: 1.1252 - val_accuracy: 0.8391
# Epoch 8/50
# 261/261 [==============================] - 67s 257ms/step - loss: 0.0345 - accuracy: 0.9998 - val_loss: 1.3008 - val_accuracy: 0.7924
# Epoch 9/50
# 261/261 [==============================] - 68s 260ms/step - loss: 0.0637 - accuracy: 0.9914 - val_loss: 1.1759 - val_accuracy: 0.8161
# Epoch 10/50
# 261/261 [==============================] - 67s 257ms/step - loss: 0.0303 - accuracy: 1.0000 - val_loss: 1.1040 - val_accuracy: 0.8204
# Epoch 11/50
# 261/261 [==============================] - 67s 255ms/step - loss: 0.0256 - accuracy: 1.0000 - val_loss: 1.0933 - val_accuracy: 0.8261
# Epoch 12/50
# 261/261 [==============================] - 67s 257ms/step - loss: 0.0225 - accuracy: 1.0000 - val_loss: 1.0622 - val_accuracy: 0.8384
# Epoch 13/50
# 261/261 [==============================] - 67s 256ms/step - loss: 0.0201 - accuracy: 1.0000 - val_loss: 1.1217 - val_accuracy: 0.8218
# Epoch 14/50
# 261/261 [==============================] - 66s 253ms/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 1.0902 - val_accuracy: 0.8333
# Epoch 15/50
# 261/261 [==============================] - 65s 250ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 1.1506 - val_accuracy: 0.8405
# Epoch 16/50
# 261/261 [==============================] - 70s 267ms/step - loss: 0.0155 - accuracy: 1.0000 - val_loss: 1.1330 - val_accuracy: 0.8384
# Epoch 17/50
# 261/261 [==============================] - 78s 297ms/step - loss: 0.0449 - accuracy: 0.9931 - val_loss: 1.0950 - val_accuracy: 0.8448
# Epoch 18/50
# 261/261 [==============================] - 63s 239ms/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 1.0346 - val_accuracy: 0.8434
# Epoch 19/50
# 261/261 [==============================] - 64s 244ms/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 1.0572 - val_accuracy: 0.8341
# Epoch 20/50
# 261/261 [==============================] - 62s 237ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 1.0283 - val_accuracy: 0.8506
# Epoch 21/50
# 261/261 [==============================] - 58s 221ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 1.0519 - val_accuracy: 0.8384
# Epoch 22/50
# 261/261 [==============================] - 57s 216ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 1.1264 - val_accuracy: 0.8341
# Epoch 23/50
# 261/261 [==============================] - 59s 224ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 1.0277 - val_accuracy: 0.8513
# Epoch 24/50
# 261/261 [==============================] - 65s 249ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 1.0967 - val_accuracy: 0.8470
# Epoch 25/50
# 261/261 [==============================] - 59s 227ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 1.1031 - val_accuracy: 0.8369
# Epoch 26/50
# 261/261 [==============================] - 63s 241ms/step - loss: 0.0377 - accuracy: 0.9926 - val_loss: 1.3166 - val_accuracy: 0.7938
# Epoch 27/50
# 261/261 [==============================] - 68s 261ms/step - loss: 0.0211 - accuracy: 0.9990 - val_loss: 1.1156 - val_accuracy: 0.8096
# Epoch 28/50
# 261/261 [==============================] - 70s 268ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 1.0347 - val_accuracy: 0.8341
# Epoch 29/50
# 261/261 [==============================] - 65s 250ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 1.0644 - val_accuracy: 0.8283
# Epoch 30/50
# 261/261 [==============================] - 60s 230ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 1.0817 - val_accuracy: 0.8391
# Epoch 31/50
# 261/261 [==============================] - 60s 230ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 1.0864 - val_accuracy: 0.8434
# Epoch 32/50
# 261/261 [==============================] - 59s 226ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 1.1238 - val_accuracy: 0.8384
# Epoch 33/50
# 261/261 [==============================] - 62s 238ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 1.1071 - val_accuracy: 0.8470
# Epoch 34/50
# 261/261 [==============================] - 63s 242ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 1.1493 - val_accuracy: 0.8283
# Epoch 35/50
# 261/261 [==============================] - 63s 241ms/step - loss: 0.0115 - accuracy: 0.9995 - val_loss: 1.2613 - val_accuracy: 0.8161
# Epoch 36/50
# 261/261 [==============================] - 62s 236ms/step - loss: 0.0200 - accuracy: 0.9983 - val_loss: 1.2020 - val_accuracy: 0.8125
# Epoch 37/50
# 261/261 [==============================] - 59s 225ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 1.0844 - val_accuracy: 0.8269
# Epoch 38/50
# 261/261 [==============================] - 61s 235ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 1.1030 - val_accuracy: 0.8204
# Epoch 39/50
# 261/261 [==============================] - 51s 194ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 1.1519 - val_accuracy: 0.8297
# Epoch 40/50
# 261/261 [==============================] - 50s 191ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 1.1339 - val_accuracy: 0.8240
# Epoch 41/50
# 261/261 [==============================] - 52s 199ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 1.1166 - val_accuracy: 0.8391
# Epoch 42/50
# 261/261 [==============================] - 57s 219ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 1.1565 - val_accuracy: 0.8269
# Epoch 43/50
# 261/261 [==============================] - 57s 219ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 1.1171 - val_accuracy: 0.8499
# Epoch 44/50
# 261/261 [==============================] - 57s 219ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 1.1626 - val_accuracy: 0.8434
# Epoch 45/50
# 261/261 [==============================] - 58s 223ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 1.1592 - val_accuracy: 0.8477
# Epoch 46/50
# 261/261 [==============================] - 58s 223ms/step - loss: 0.0148 - accuracy: 0.9981 - val_loss: 0.9544 - val_accuracy: 0.8111
# Epoch 47/50
# 261/261 [==============================] - 59s 225ms/step - loss: 0.0151 - accuracy: 0.9995 - val_loss: 1.1930 - val_accuracy: 0.8218
# Epoch 48/50
# 261/261 [==============================] - 58s 223ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 1.0393 - val_accuracy: 0.8477
# Epoch 49/50
# 261/261 [==============================] - 59s 225ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 1.0545 - val_accuracy: 0.8484
# Epoch 50/50
# 261/261 [==============================] - 60s 229ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 1.1020 - val_accuracy: 0.8391

# %%
loss=model2.history.__dict__['history']['loss']
accuracy=model2.history.__dict__['history']['accuracy']

from matplotlib import pyplot as plt 

plt.plot(model2.history.__dict__['history']['loss'], label='Training data')
plt.ylabel('Loss value')
plt.xlabel('No. epoch')
plt.show()

# Plot history: Accuracy
plt.plot(model2.history.__dict__['history']['accuracy'], label='Training data')
plt.ylabel('%')
plt.xlabel('No. epoch')
plt.show()

# %% [markdown]
# ## Part3 - ** only for 574 students **.
# 1. Fine tune the well pre-trained model, Resnet 50, with different freeze layers.
# First,  load pre-trained resnet 50 from library.
# Second, Fine-tune the model to fit our project, 10-classes.
# Third,  freeze different layers, plot different training process with different frozen layers (at least three different layers).

# %%
# load pre-trained resnet 50 from libarary
# your Code HERE


# Fine-tune the model to fit our project  
# your Code HERE


# define the freeze layers 
# your Code HERE


# Please compile the new model
#model.compile()


#Train the model with training and validation set
#model.fit()
